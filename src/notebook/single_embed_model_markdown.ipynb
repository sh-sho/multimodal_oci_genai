# %% [markdown]
# ### Chat with Markdown

# %%
import os
from langchain_core.documents import Document
from langchain.callbacks.manager import CallbackManagerForRetrieverRun
from langchain.schema import BaseRetriever
from typing import List
import oracledb
import base64
import json
import pandas as pd
from openpyxl import load_workbook
from openpyxl.drawing.image import Image as XLImage
from PIL import Image
import io
import pandas as pd
from dotenv import find_dotenv, load_dotenv
from collections import Counter


from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import PromptTemplate
from langchain_community.embeddings import OCIGenAIEmbeddings
from langchain_community.chat_models import ChatOCIGenAI
from langchain_community.document_loaders import UnstructuredExcelLoader

_ = load_dotenv(find_dotenv())
oracledb.init_oracle_client()

UN = os.getenv("UN")
PW = os.getenv("PW")
DSN = os.getenv("DSN")
OCI_COMPARTMENT_ID = os.getenv("OCI_COMPARTMENT_ID")

# %%
# Utils
def get_embedding(text: str) -> list:
  embeddings = OCIGenAIEmbeddings(
    model_id="cohere.embed-multilingual-v3.0",
    service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
    compartment_id=OCI_COMPARTMENT_ID,
  )
  return embeddings.embed_query(text)

# %%
def extract_tables_and_images(file_path, output_dir="images"):
  os.makedirs(output_dir, exist_ok=True)
  wb = load_workbook(file_path)
  e_wb = pd.ExcelFile(file_path)
  result = []

  for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"worksheet: {ws}")
    # --- 表の抽出 ---
    df = pd.read_excel(e_wb, sheet_name=sheet_name)
    markdown = df.to_markdown(index=False)
    print(f"Markdown Table:\n{markdown}")
    result.append({
      "type": "text",
      "sheet": sheet_name,
      "markdown": markdown,
      "raw": df
    })
  return result

# %%
def summarize_text(text: str) -> str:
  prompt = PromptTemplate(
      input_variables=["text"],
      template="以下の内容を要約してください:\n{text}"
  )
  llm = ChatOCIGenAI(
    model_id="cohere.command-a-03-2025",
    service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
    compartment_id=OCI_COMPARTMENT_ID,
    model_kwargs={"temperature": 0.7, "max_tokens": 500},
    )

  chain = ({"text": RunnablePassthrough() } 
           | prompt 
           | llm 
           | StrOutputParser()
  )
  result = chain.invoke(text)
  return result

# %%
def save_markdown_content(file_name: str, file_path: str, summary: str, embedding: list, markdown: str):
  sql = """
        INSERT INTO embedding_contents (name, summary, embedding, file_path, content_type, markdown)
        VALUES (:name, :summary, :embedding, :file_path, :content_type, :markdown)
      """

  try:
    with oracledb.connect(user=UN, password=PW, dsn=DSN) as conn:
      with conn.cursor() as cursor:
        # cursor.setinputsizes(oracledb.DB_TYPE_VECTOR)
        params = {
          'name': file_name,
          'summary': summary,
          'embedding': str(embedding),
          'file_path': file_path,
          'content_type': 'text',
          'markdown': markdown
        }
        cursor.execute(sql, params)
        
        print(f"Success insert {file_name} into embedding_contents")
      conn.commit()
  except oracledb.DatabaseError as e:
    error, = e.args
    print(f"Error at save_markdown_content: {error.code}")
    print(f"Oracle error code: {error.code}")
    print(f"Oracle error message: {error.message}")
  except Exception as e:
    print(f"Error:save_image_content: {e}")
    return None

# %%
def process_excel(file_path):
  contents = extract_tables_and_images(file_path)

  for content in contents:
    if content["type"] == "text":
      print(f"table: {content['sheet']}")
      summary = summarize_text(content["markdown"])
      print(summary)
      embedding = get_embedding(summary)
      print(f"file_path: {file_path}")
      print(f"file_name: {content['sheet']}")
      save_markdown_content(
        file_name=content["sheet"],
        file_path=file_path,
        summary=summary,
        embedding=embedding,
        markdown=content["markdown"]
        )
  return contents

# %%
process_excel("../../data/fy25q3-supplemental.xlsx")
# Out:
# worksheet: <Worksheet "Cover">
# Markdown Table:
# |   Unnamed: 0 | Unnamed: 1                                                       | Unnamed: 2                                                 |   Unnamed: 3 |   Unnamed: 4 |   Unnamed: 5 |   Unnamed: 6 |   Unnamed: 7 | Unnamed: 8                                                       |
# |-------------:|:-----------------------------------------------------------------|:-----------------------------------------------------------|-------------:|-------------:|-------------:|-------------:|-------------:|:-----------------------------------------------------------------|
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | 2025年5月期(FY25)第3四半期　業績補足資料                         | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | 3rd Quarter, Fiscal Year ending May 2025 (FY25) Business Results | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | (Supplemental Information and Historical Facts)                  | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | 2025-03-21 00:00:00                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | 1.                                                               | セグメント別データおよび営業経費 / Segmental Info and Opex |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | 2.                                                               | 会社概要　Corporate Overview                               |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | Oracle Corporation Japan (TSE 4716)                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | nan                                                              |
# |          nan | nan                                                              | nan                                                        |          nan |          nan |          nan |          nan |          nan | http://www.oracle.com/jp/corporate/investor-relations/index.html |
# worksheet: <Worksheet "Segmental info & Opex">
# Markdown Table:
# |   Unnamed: 0 | セグメント別データおよび営業経費 / Segmental Info and Opex                                                                                                   | Unnamed: 2                                 | Unnamed: 3         |   Unnamed: 4 |   Unnamed: 5 | Unnamed: 6   | Unnamed: 7   | Unnamed: 8          | Unnamed: 9   | Unnamed: 10   | Unnamed: 11   | Unnamed: 12   | Unnamed: 13         | Unnamed: 14   | Unnamed: 15                       |
# |-------------:|:-------------------------------------------------------------------------------------------------------------------------------------------------------------|:-------------------------------------------|:-------------------|-------------:|-------------:|:-------------|:-------------|:--------------------|:-------------|:--------------|:--------------|:--------------|:--------------------|:--------------|:----------------------------------|
# |          nan | 売上高 / Total Net Sales                                                                                                                                     | nan                                        | nan                |          nan |          nan | Q3           | nan          | nan                 | nan          | nan           | nan           | nan           | nan                 | nan           | （百万円 Millions of Yen, %=YoY） |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | nan          | nan          | 2025-05-01 00:00:00 | nan          | nan           | nan           | nan           | 2024-05-01 00:00:00 | nan           | nan                               |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | Q1           | Q2           | Q3                  | Q4           | Total         | Q1            | Q2            | Q3                  | Q4            | Total                             |
# |          nan | nan                                                                                                                                                          | nan                                        | クラウドサービス   |          nan |          nan | 13915        | 14368        | 16711               | nan          | 44995         | 12742         | 11110         | 11726               | 12678         | 48257                             |
# |              |                                                                                                                                                              |                                            | Cloud Services     |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 0.092        | 0.293        | 0.425               | nan          | 0.265         | 0.374         | 0.383         | 0.332               | 0.243         | 0.329                             |
# |          nan | nan                                                                                                                                                          | nan                                        | ライセンスサポート |          nan |          nan | 27969        | 28190        | 27976               | nan          | 84136         | 26991         | 27269         | 27527               | 27743         | 109531                            |
# |              |                                                                                                                                                              |                                            | License Support    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 0.036        | 0.034        | 0.016               | nan          | 0.029         | 0.029         | 0.036         | 0.041               | 0.04          | 0.037                             |
# |          nan | nan                                                                                                                                                          | クラウドサービス＆ライセンスサポート       | nan                |          nan |          nan | 41885        | 42558        | 44688               | nan          | 129132        | 39733         | 38379         | 39253               | 40422         | 157789                            |
# |              |                                                                                                                                                              | Cloud Services & License Support           |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 5.4%         | 0.109        | 0.138               | nan          | 10.0%         | 11.9%         | 11.7%         | 11.4%               | 9.6%          | 11.1%                             |
# |          nan | nan                                                                                                                                                          | クラウドライセンス＆オンプレミスライセンス | nan                |          nan |          nan | 12551        | 9352         | 12041               | nan          | 33946         | 8436          | 11839         | 11022               | 15987         | 47285                             |
# |              |                                                                                                                                                              | Cloud License & On Premise License         |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 48.8%        | -21.0%       | 9.2%                | nan          | 8.5%          | 22.5%         | -5.9%         | -3.9%               | -5.6%         | -1.2%                             |
# |          nan | クラウド＆ライセンス                                                                                                                                         | nan                                        | nan                |          nan |          nan | 54437        | 51911        | 56730               | nan          | 163079        | 48170         | 50218         | 50276               | 56409         | 205074                            |
# |              | Cloud & License                                                                                                                                              |                                            |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 13.0%        | 3.4%         | 12.8%               | nan          | 9.7%          | 13.7%         | 7.0%          | 7.6%                | 4.8%          | 8.0%                              |
# |          nan | ハードウェア･システムズ                                                                                                                                      | nan                                        | nan                |          nan |          nan | 3610         | 3159         | 4495                | nan          | 11266         | 3819          | 4226          | 3748                | 5101          | 16896                             |
# |              | Hardware                                                                                                                                                     |                                            |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | -5.5%        | -25.2%       | 19.9%               | nan          | -4.5%         | 20.1%         | -1.2%         | -1.8%               | 2.7%          | 4.0%                              |
# |          nan | サービス                                                                                                                                                     | nan                                        | nan                |          nan |          nan | 5867         | 6308         | 6371                | nan          | 18546         | 5382          | 5602          | 5438                | 6148          | 22571                             |
# |              | Service                                                                                                                                                      |                                            |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 9.0%         | 12.6%        | 17.1%               | nan          | 12.9%         | -1.4%         | 0.9%          | 11.0%               | 25.2%         | 8.4%                              |
# |          nan | 合計                                                                                                                                                         | nan                                        | nan                |          nan |          nan | 63915        | 61379        | 67597               | nan          | 192892        | 57372         | 60047         | 59464               | 67658         | 244542                            |
# |              | Total Net Sales                                                                                                                                              |                                            |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 11.4%        | 2.2%         | 13.7%               | nan          | 9.1%          | 12.5%         | 5.8%          | 7.3%                | 6.2%          | 7.8%                              |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | nan          | nan          | nan                 | nan          | nan           | nan           | nan           | nan                 | nan           | nan                               |
# |          nan | 営業利益 / Operating Income                                                                                                                                  | nan                                        | nan                |          nan |          nan | nan          | nan          | nan                 | nan          | nan           | nan           | nan           | nan                 | nan           | nan                               |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | nan          | nan          | 2025-05-01 00:00:00 | nan          | nan           | nan           | nan           | 2024-05-01 00:00:00 | nan           | nan                               |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | Q1           | Q2           | Q3                  | Q4           | Total         | Q1            | Q2            | Q3                  | Q4            | Total                             |
# |          nan | クラウド＆ライセンス                                                                                                                                         | nan                                        | nan                |          nan |          nan | 21997        | 19233        | 21966               | nan          | 63198         | 18574         | 19293         | 19685               | 22033         | 79586                             |
# |              | Cloud & License                                                                                                                                              |                                            |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 18.4%        | -0.3%        | 11.6%               | nan          | 9.8%          | 14.2%         | 5.7%          | 9.6%                | 2.9%          | 7.7%                              |
# |          nan | ハードウェア･システムズ                                                                                                                                      | nan                                        | nan                |          nan |          nan | 134          | 106          | 150                 | nan          | 391           | 160           | 116           | 158                 | 255           | 691                               |
# |              | Hardware                                                                                                                                                     |                                            |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | -16.0%       | -9.1%        | -4.6%               | nan          | -10.0%        | 20.8%         | -30.0%        | 19.5%               | 32.3%         | 10.5%                             |
# |          nan | サービス                                                                                                                                                     | nan                                        | nan                |          nan |          nan | 1302         | 1428         | 1421                | nan          | 4153          | 923           | 1523          | 837                 | 1480          | 4764                              |
# |              | Services                                                                                                                                                     |                                            |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 41.1%        | -6.2%        | 69.8%               | nan          | 26.5%         | -16.7%        | 22.5%         | -12.3%              | 2.1%          | 0.2%                              |
# |          nan | 共通経費（全社費用)                                                                                                                                          | nan                                        | nan                |          nan |          nan | -1241        | -1049        | -1232               | nan          | -3523         | -1190         | -1080         | -1296               | -1656         | -5222                             |
# |              | Adjustment                                                                                                                                                   |                                            |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 4.3%         | -2.8%        | -4.9%               | nan          | -1.2%         | -12.2%        | -2.2%         | 13.6%               | 30.8%         | 7.3%                              |
# |          nan | 営業利益                                                                                                                                                     | nan                                        | nan                |          nan |          nan | 22194        | 19718        | 22306               | nan          | 64219         | 18468         | 19853         | 19384               | 22113         | 79820                             |
# |              | Operating income                                                                                                                                             |                                            |                    |              |              |              |              |                     |              |               |               |               |                     |               |                                   |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | 20.2%        | -0.7%        | 15.1%               | nan          | 11.3%         | 14.4%         | 7.0%          | 8.3%                | 1.5%          | 7.3%                              |
# |          nan | 営業経費主要科目 (売上原価+販売費及び一般管理費) / Operating Expenses (Sum of COGS and SG&A )                                                                | nan                                        | nan                |          nan |          nan | nan          | nan          | nan                 | nan          | nan           | nan           | nan           | nan                 | nan           | nan                               |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | nan          | nan          | 2025-05-01 00:00:00 | nan          | nan           | nan           | nan           | 2024-05-01 00:00:00 | nan           | nan                               |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | Q1           | Q2           | Q3                  | Q4           | Total         | Q1            | Q2            | Q3                  | Q4            | Total                             |
# |          nan | ロイヤルティ（Royalty）                                                                                                                                      | nan                                        | nan                |          nan |          nan | 24089        | 23342        | 25684               | nan          | 73115         | 20850         | 22114         | 22046               | 25301         | 90313                             |
# |          nan | ハードウェア・システムズ仕入原価  (Hardware Purchasing Expenses)                                                                                             | nan                                        | nan                |          nan |          nan | 3093         | 2672         | 3907                | nan          | 9673          | 3204          | 3695          | 3170                | 4399          | 14469                             |
# |          nan | 人件費（Human Resources）                                                                                                                                    | nan                                        | nan                |          nan |          nan | 7637         | 8102         | 8820                | nan          | 24559         | 7857          | 7975          | 8207                | 8215          | 32256                             |
# |          nan | 業務委託費 (Outsourcing）                                                                                                                                    | nan                                        | nan                |          nan |          nan | 4910         | 5694         | 4797                | nan          | 15403         | 5226          | 4658          | 4817                | 5615          | 20317                             |
# |          nan | ファシリティ関連（Facility）*                                                                                                                                | nan                                        | nan                |          nan |          nan | 526          | 547          | 548                 | nan          | 1622          | 606           | 419           | 717                 | 431           | 2174                              |
# |          nan | その他（Others）                                                                                                                                             | nan                                        | nan                |          nan |          nan | 1463         | 1301         | 1532                | nan          | 4297          | 1158          | 1330          | 1119                | 1581          | 5190                              |
# |          nan | 合計/Total                                                                                                                                                   | nan                                        | nan                |          nan |          nan | 41721        | 41660        | 45290               | nan          | 128672        | 38903         | 40193         | 40079               | 45545         | 164722                            |
# |          nan | * ファシリティには賃借料、減価償却費、消耗品費、水道光熱費が含まれる / Facility includes rent, depreciation & amortization, supplies expenses and utilities. | nan                                        | nan                |          nan |          nan | nan          | nan          | nan                 | nan          | nan           | nan           | nan           | nan                 | nan           | nan                               |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | nan          | nan          | nan                 | nan          | nan           | nan           | nan           | nan                 | nan           | nan                               |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | nan          | nan          | 2025-05-01 00:00:00 | nan          | nan           | nan           | nan           | 2024-05-01 00:00:00 | nan           | nan                               |
# |          nan | nan                                                                                                                                                          | nan                                        | nan                |          nan |          nan | Q1           | Q2           | Q3                  | Q4           | nan           | Q1            | Q2            | Q3                  | Q4            | nan                               |
# |          nan | 従業員数 / Number of Employees                                                                                                                               | nan                                        | nan                |          nan |          nan | 2248         | 2257         | 2253                | nan          | -             | 2346          | 2296          | 2268                | 2257          | -                                 |
# worksheet: <Worksheet "Corporate_Overview">
# Markdown Table:
# |   Unnamed: 0 | 会社概要　Corporate Overview   | Unnamed: 2                       | Unnamed: 3                                                            | Unnamed: 4                         |   Unnamed: 5 |   Unnamed: 6 |   Unnamed: 7 |   Unnamed: 8 |   Unnamed: 9 |   Unnamed: 10 | Unnamed: 11               |
# |-------------:|:-------------------------------|:---------------------------------|:----------------------------------------------------------------------|:-----------------------------------|-------------:|-------------:|-------------:|-------------:|-------------:|--------------:|:--------------------------|
# |          nan | nan                            | nan                              | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | ●                              | 商号                             | 日本オラクル株式会社                                                  | ●業績推移  Revenues and Net Income |          nan |          nan |          nan |          nan |          nan |           nan | (百万円  Millions of Yen) |
# |          nan | nan                            | Company Name                     | Oracle Corporation Japan                                              | 売上高 Revenue                     |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | ●                              | 設立                             | 1985年10月15日                                                        | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | Established                      | October 15, 1985                                                      | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | ●                              | 資本金                           | 25212                                                                 | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | Paid-In Capital                  | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | ●                              | 代表執行役                       | 内海 寛子                                                             | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | Representative Executive Officer | Hiroko Utsumi                                                         | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | ●                              | 従業員数                         | 2253                                                                  | 当期純利益 Net Income              |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | Number of Employees              | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | ●                              | 事業内容                         | 企業の事業活動の基盤となるソフトウェア･ハードウェア、クラウドサービス | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | Scope of Business                | ならびにそれらの利用を支援する各種サービスの提供                      | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | Sales of software & hardware products, Cloud services and             | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | provision of various kinds of services supporting the use             | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | of such products for businesses                                       | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | ●                              | 本社所在地                       | 東京都港区北青山2-5-8　オラクル青山センター                           | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | Head office                      | Oracle Aoyama Center 2-5-8, Kita-Aoyama, Minato-ku, Tokyo             | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | nan                                                                   | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# |          nan | nan                            | nan                              | 2025年2月28日現在 / as of February 28, 2025                           | nan                                |          nan |          nan |          nan |          nan |          nan |           nan | nan                       |
# worksheet: <Worksheet "1.Rev YoY">
# Markdown Table:
# | Unnamed: 0   | Unnamed: 1   | 1.売上高対前年同期比　Revenue YoY   |
# |--------------|--------------|-------------------------------------|
# worksheet: <Worksheet "2.Ope YoY">
# Markdown Table:
# | Unnamed: 0   | Unnamed: 1   | 2.営業利益対前年同期比　Operating Income YoY   |
# |--------------|--------------|------------------------------------------------|
# worksheet: <Worksheet "3.Summary">
# Markdown Table:
# |   Unnamed: 0 | 3.直近業績要約　Summary of Recent Operating Results                                                                                                                                                      | Unnamed: 2                                               | Unnamed: 3   | Unnamed: 4   | Unnamed: 5          | Unnamed: 6   | Unnamed: 7          | Unnamed: 8   | Unnamed: 9   | Unnamed: 10         | Unnamed: 11   | Unnamed: 12                | Unnamed: 13         | Unnamed: 14         | Unnamed: 15         | Unnamed: 16         |
# |-------------:|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------|:-------------|:-------------|:--------------------|:-------------|:--------------------|:-------------|:-------------|:--------------------|:--------------|:---------------------------|:--------------------|:--------------------|:--------------------|:--------------------|
# |          nan | Q3                                                                                                                                                                                                       | nan                                                      | nan          | nan          | nan                 | nan          | nan                 | nan          | nan          | nan                 | nan           | （百万円 Millions of Yen） | nan                 | nan                 | nan                 | nan                 |
# |          nan | nan                                                                                                                                                                                                      | nan                                                      | nan          | nan          | 2025-05-01 00:00:00 | nan          | 2023-05-01 00:00:00 | nan          | nan          | 2024-05-01 00:00:00 | nan           | 2024-05-01 00:00:00        | 2023-05-01 00:00:00 | 2022-05-01 00:00:00 | 2021-05-01 00:00:00 | 2020-05-01 00:00:00 |
# |          nan | nan                                                                                                                                                                                                      | nan                                                      | Q1           | Q2           | Q3                  | Q4           | Total               | Q1           | Q2           | Q3                  | Q4            | Total                      | Total               | Total               | Total               | Total               |
# |          nan | 売上高 / Total Revenue                                                                                                                                                                                   | nan                                                      | 63915        | 61379        | 67597               | nan          | 192892              | 57372        | 60047        | 59464               | 67658         | 244542                     | 226914              | 214691              | 208523              | 211357              |
# |          nan | 売上原価 / Cost of Goods and Sales                                                                                                                                                                       | nan                                                      | 33500        | 33390        | 36747               | nan          | 103637              | 30726        | 31968        | 31787               | 36515         | 130996                     | 118622              | 109139              | 106764              | 109110              |
# ...
#   31         NaN                                                NaN
#   32         NaN                                                NaN
#   33         NaN                                                NaN
#   34         NaN                                                NaN
#   35         NaN                                                NaN
#   36         NaN                                                NaN
#   37         NaN                                                NaN
#   38         NaN                                             資産合計
#   39         NaN                                       Total assets
#   40         NaN  * 第1～第3四半期末における「*」の科目の残高は「その他」に含まれております / Bala...
#   41         NaN                                                 *
#
#                                              Unnamed: 2  \
#   0                                                 NaN
#   1                                                 NaN
#   2                                                 NaN
#   3                                                 NaN
#   4                                                 NaN
#   5                                            現金及び預金
#   6                                   Cash and deposits
#   7                                               売掛金
#   8                                 Accounts receivable
#   9                                                 前渡金
#   10                      Advance payments to suppliers
#   11                                               前払費用
#   12                                   Prepaid expenses
#   13                                               未収入金
#   14                          Accounts receivable-other
#   15                                          関係会社短期貸付金
#   16  Short-term loans receivable from subsidiaries ...
#   17                                              その他
#   18                                             Others
#   19                                            貸倒引当金
#   20                    Allowance for doubtful accounts
#   21                                                NaN
#   22                                                NaN
#   23                    有形固定資産 / Property and equipment
#   24                                                NaN
#   25                                                NaN
#   26                                                NaN
#   27                                                NaN
#   28                                                NaN
#   29                                                NaN
#   30                   無形固定資産 / Intangible fixed assets
#   31                                           投資その他の資産
#   32                       Investments and other assets
#   33                                                NaN
#   34                                                NaN
#   35                                                NaN
#   36                                                NaN
#   37                                                NaN
#   38                                                NaN
#   39                                                NaN
#   40                                                NaN
#   41  2021年5月期まで、契約負債は前受金として開示しております。/ Until FY21, C...
#
#                                              Unnamed: 3 Unnamed: 4 Unnamed: 5  \
#   0                                                 NaN        NaN        NaN
#   1                                                 NaN        NaN        NaN
#   2                                                 NaN     2021/5     2022/5
#   3                                                 NaN      81038      84800
#   4                                                 NaN        NaN        NaN
#   5                                                 NaN      53964      60142
#   6                                                 NaN        NaN        NaN
#   7                                                 NaN      18799      20784
#   8                                                 NaN        NaN        NaN
#   9                                                 NaN       3399         62
#   10                                                NaN        NaN        NaN
#   11                                                NaN        109        108
#   12                                                NaN        NaN        NaN
#   13                                                NaN         *          *
#   14                                                NaN        NaN        NaN
#   15                                                NaN         -          -
#   16                                                NaN        NaN        NaN
#   17                                                NaN       4784       3721
#   18                                                NaN        NaN        NaN
#   19                                                NaN        -20        -20
#   20                                                NaN        NaN        NaN
#   21                                                NaN        NaN        NaN
#   22                                                NaN     252960     152068
#   23                                                NaN      36894      35796
#   24                                                 土地      26057      26057
#   25                                               Land        NaN        NaN
#   26                                       建物及び建物付属設備         9487       8628
#   27                  Buildings and accessory equipment        NaN        NaN
#   28                                             器具及び備品       1349       1111
#   29                      Tools, furniture and fixtures        NaN        NaN
#   30                                                NaN          0          1
#   31                                                NaN     216065     116270
#   32                                                NaN        NaN        NaN
#   33                                          関係会社長期貸付金     210000     110000
#   34  Long-term loans receivable from subsidiaries a...        NaN        NaN
#   35                                                その他       6065       6270
#   36                                             Others        NaN        NaN
#   37                                                NaN        NaN        NaN
#   38                                                NaN     333999     236868
#   39                                                NaN        NaN        NaN
#   40                                                NaN        NaN        NaN
#   41                                                NaN        NaN        NaN
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  \
#   0         NaN        NaN        NaN         NaN
#   1         NaN        NaN        NaN         NaN
#   2      2023/5     2024/5     2025/2         NaN
#   3      130831     118829     159417         NaN
#   4         NaN        NaN        NaN         NaN
#   5      104531      91904      26125         NaN
#   6         NaN        NaN        NaN         NaN
#   7       21350      21202      19465         NaN
#   8         NaN        NaN        NaN         NaN
#   9        1534       2910          *         NaN
#   10        NaN        NaN        NaN         NaN
#   11         44         49          *         NaN
#   12        NaN        NaN        NaN         NaN
#   13         *          *           *         NaN
#   14        NaN        NaN        NaN         NaN
#   15         -          -      110000         NaN
#   16        NaN        NaN        NaN         NaN
#   17       3389       2781       3846         NaN
#   18        NaN        NaN        NaN         NaN
#   19        -20        -20        -20         NaN
#   20        NaN        NaN        NaN         NaN
#   21        NaN        NaN        NaN         NaN
#   22     150184     221329     112398         NaN
#   23      34973      34236      35153         NaN
#   24      26057      26057      26057         NaN
#   25        NaN        NaN        NaN         NaN
#   26       7824       6995       6491         NaN
#   27        NaN        NaN        NaN         NaN
#   28       1092       1184       2605         NaN
#   29        NaN        NaN        NaN         NaN
#   30          1          0          0         NaN
#   31     115209     187092      77243         NaN
#   32        NaN        NaN        NaN         NaN
#   33     110000     182000      72000         NaN
#   34        NaN        NaN        NaN         NaN
#   35       5209       5092       5243         NaN
#   36        NaN        NaN        NaN         NaN
#   37        NaN        NaN        NaN         NaN
#   38     281015     340159     271815         NaN
#   39        NaN        NaN        NaN         NaN
#   40        NaN        NaN        NaN         NaN
#   41        NaN        NaN        NaN         NaN
#
#                              Unnamed: 10              Unnamed: 11  Unnamed: 12  \
#   0                                  NaN                      NaN          NaN
#   1   負債･資本の部　Liabilities and Net Assets                      NaN          NaN
#   2                          決算期  Period                      NaN          NaN
#   3                                 流動負債                      NaN          NaN
#   4                  Current liabilities                      NaN          NaN
#   5                                  NaN                      買掛金          NaN
#   6                                  NaN          Account payable          NaN
#   7                                  NaN                      未払金          NaN
#   8                                  NaN   Accrued amount payable          NaN
#   9                                  NaN                   未払法人税等          NaN
#   10                                 NaN     Accrued income taxes          NaN
#   11                                 NaN                   未払消費税等          NaN
#   12                                 NaN  Accrued consumption tax          NaN
#   13                                 NaN                     契約負債          NaN
#   14                                 NaN     Contract liabilities          NaN
#   15                                 NaN                      その他          NaN
#   16                                 NaN                   Others          NaN
#   17                                固定負債                      NaN          NaN
#   18              Noncurrent liabilities                      NaN          NaN
#   19                                 NaN                      その他          NaN
#   20                                 NaN                   Others          NaN
#   21                                負債合計                      NaN          NaN
#   22                   Total liabilities                      NaN          NaN
#   23                                 NaN                      NaN          NaN
#   24                                 資本金                      NaN          NaN
#   25                       Capital stock                      NaN          NaN
#   26                               資本剰余金                      NaN          NaN
#   27                     Capital surplus                      NaN          NaN
#   28                               利益剰余金                      NaN          NaN
#   29                   Retained earnings                      NaN          NaN
#   30                                自己株式                      NaN          NaN
#   31                      Treasury stock                      NaN          NaN
#   32                              株主資本合計                      NaN          NaN
#   33          Total shareholders' equity                      NaN          NaN
#   34                               新株予約権                      NaN          NaN
#   35             Stock acquisition right                      NaN          NaN
#   36                               純資産合計                      NaN          NaN
#   37                    Total net assets                      NaN          NaN
#   38                            負債・純資産合計                      NaN          NaN
#   39    Total liabilities and net assets                      NaN          NaN
#   40                                 NaN                      NaN          NaN
#   41                                 NaN                      NaN          NaN
#
#      Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16            Unnamed: 17
#   0          NaN         NaN         NaN         NaN  （百万円 Millions of Yen）
#   1          NaN         NaN         NaN         NaN                    NaN
#   2       2021/5      2022/5      2023/5      2024/5                 2025/2
#   3       113999      111512      125161      148363                 124046
#   4          NaN         NaN         NaN         NaN                    NaN
#   5         9379        8918       10193       12618                  14058
#   6          NaN         NaN         NaN         NaN                    NaN
#   7         3743        4672        4818        5031                   4409
#   8          NaN         NaN         NaN         NaN                    NaN
#   9        13982       12313       10659       14847                   7789
#   10         NaN         NaN         NaN         NaN                    NaN
#   11          *           *           *           *                       *
#   12         NaN         NaN         NaN         NaN                    NaN
#   13       80206       80047       93088      108589                  90425
#   14         NaN         NaN         NaN         NaN                    NaN
#   15        6686        5560        6400        7276                   7364
#   16         NaN         NaN         NaN         NaN                    NaN
#   17           0           0           0           -                      -
#   18         NaN         NaN         NaN         NaN                    NaN
#   19           0           0           0           -                      -
#   20         NaN         NaN         NaN         NaN                    NaN
#   21      113999      111513      125161      148363                 124046
#   22         NaN         NaN         NaN         NaN                    NaN
#   23         NaN         NaN         NaN         NaN                    NaN
#   24       25033       25067       25111       25175                  25212
#   25         NaN         NaN         NaN         NaN                    NaN
#   26        8384        8418        8462        8526                   8563
#   27         NaN         NaN         NaN         NaN                    NaN
#   28      188924       93156      124646      159472                 117869
#   29         NaN         NaN         NaN         NaN                    NaN
#   30       -2461       -1399       -2452       -1438                  -3922
#   31         NaN         NaN         NaN         NaN                    NaN
#   32      219881      125243      155768      191735                 147722
#   33         NaN         NaN         NaN         NaN                    NaN
#   34         118         111          85          59                     45
#   35         NaN         NaN         NaN         NaN                    NaN
#   36      219999      125355      155854      191795                 147768
#   37         NaN         NaN         NaN         NaN                    NaN
#   38      333999      236868      281015      340159                 271815
#   39         NaN         NaN         NaN         NaN                    NaN
#   40         NaN         NaN         NaN         NaN                    NaN
#   41         NaN         NaN         NaN         NaN                    NaN  }]

# %% [markdown]
# #### Create Embedding Retriever

# %%
class CustomEmbeddingRetriever(BaseRetriever):
    """
    Custom image retriever.
    """

    def _get_relevant_documents(
        self, query: str, *, run_manager: CallbackManagerForRetrieverRun
    ) -> List[Document]:
        docs: List[Document] = []
        embed_query = str(get_embedding(query))
        try:
            with oracledb.connect(user=UN, password=PW, dsn=DSN) as connection:
                with connection.cursor() as cursor:
                    cursor.setinputsizes(oracledb.DB_TYPE_VECTOR)
                    select_sql = f"""
                        SELECT
                            id,
                            name,
                            content_type,
                            file_path,
                            summary
                        FROM
                            embedding_contents
                        ORDER BY VECTOR_DISTANCE(embedding, to_vector(:1, 1024, FLOAT32), COSINE)
                        FETCH FIRST 3 ROWS ONLY
                    """
                    cursor.execute(select_sql, [embed_query])
                    index = 1
                    for row in cursor:
                        doc = Document(
                            page_content=row[3],
                            metadata={
                                'id':row[0],
                                'name': row[1],
                                'content_type': row[2],
                                'file_path': row[3],
                                'vector_index': index
                                }
                            )
                        docs.append(doc)
                        index += 1
                connection.close()
                        
        except oracledb.DatabaseError as e:
            print(f"Database error: {e}")
            raise
        except Exception as e:
            print("Error Vector Search:", e)
        
        return docs

# %% [markdown]
# ### Create Chain

# %%
def get_text_with_markdown(query: str):
    retriever = CustomEmbeddingRetriever()
    result_content = retriever.invoke(query)
    id = result_content[0].metadata['id']

    docs: List[Document] = []
    df = pd.DataFrame()
    try:
        with oracledb.connect(user=UN, password=PW, dsn=DSN) as connection:
            with connection.cursor() as cursor:
                cursor.setinputsizes(oracledb.DB_TYPE_VECTOR)
                select_sql = f"""
                    SELECT
                        id,
                        markdown
                    FROM
                        embedding_contents
                    WHERE id = :1
                """
                cursor.execute(select_sql, [id])
                for row in cursor:
                    df_tmp = pd.DataFrame([[row[0], row[1].read()]],
                                            columns=["id", "markdown"])
                    df = pd.concat([df, df_tmp], ignore_index=True)
                
                for i in range(len(df)):
                    id = df.iloc[i, 0]
                    markdown = df.iloc[i, 1]
                    doc = Document(
                        page_content=markdown,
                        metadata={'id':id, 'vector_index': i}
                        )
                    docs.append(doc)
            connection.close()
                    
    except oracledb.DatabaseError as e:
        print(f"Database error: {e}")
        raise
    except Exception as e:
        print("Error Vector Search:", e)
    
    llm = ChatOCIGenAI(
        model_id="cohere.command-a-03-2025",
        service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id=OCI_COMPARTMENT_ID,
        )
    
    prompt = ChatPromptTemplate([
        ("system", "あなたは質疑応答のAIアシスタントです。必ず日本語で答えてください。"),
        ("human", """
         以下のMarkdownのコンテキストに基づいて質問に答えてください。
         回答は数字だけを回答してください。
         ** 質問 **
          {query} 
          
        ** コンテキスト **
        """
        f"{docs[0].page_content}"
        ),
    ])

    chain = {'query': RunnablePassthrough()} | prompt | llm | StrOutputParser()

    result = chain.invoke(query)
    return result

# %%
# response = get_text_by_text_with_markdown("2024年5月のハードウェアシステムズのTotalの売上を教えてください。")
response = get_text_with_markdown("2024/5のQ4のFacilityの経費を教えてください。")
print(response)
# Out:
# コンテキストに2024/5のQ4のFacilityの経費に関する

# %%
def get_text_by_text(query: str):
    llm = ChatOCIGenAI(
        model_id="cohere.command-a-03-2025",
        service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id=OCI_COMPARTMENT_ID,
        )
    loader = UnstructuredExcelLoader("../../data/fy25q3-supplemental.xlsx")
    docs = loader.load()
    context = "\n".join([doc.page_content for doc in docs])

    prompt = ChatPromptTemplate([
        ("system", "あなたは質疑応答のAIアシスタントです。必ず日本語で答えてください。"),
        ("human", """
         以下のコンテキストに基づいて質問に答えてください。
         回答は数字だけを回答してください。
         ** 質問 **
          {query} 
          
        ** コンテキスト **
        """ + context + """
        ** Output **
        value: int
        """),
    ])
    chain = {'query': RunnablePassthrough()} | prompt | llm | StrOutputParser()

    result = chain.invoke(query)
    return result

# %%
# response = get_text_by_text("2025年のハードウェアシステムズのTotalの売上を教えてください。")
response = get_text_by_text("2024/5のQ4のFacilityの経費を教えてください。")
print(response)
# Out:
# 431

# %%
response = get_text_by_text("Please tell me the facility expenses for Q4 of 2024/5.")
print(response)
# Out:
# 1622

# %%
query = "2024/5のQ4のFacilityの経費を教えてください。"

results_with_markdown = []
results_with_text = []

for _ in range(20):
    res = get_text_with_markdown(query)
    results_with_markdown.append(res)

for _ in range(20):
    res = get_text_by_text(query)
    results_with_text.append(res)

result_counts_with_markdown = Counter(results_with_markdown)
result_counts_with_text = Counter(results_with_text)

df_with_markdown = pd.DataFrame(
    list(result_counts_with_markdown.items()), 
    columns=["Result", "Count"]
).sort_values(by="Count", ascending=False)
df_with_text = pd.DataFrame(
    list(result_counts_with_text.items()), 
    columns=["Result", "Count"]
).sort_values(by="Count", ascending=False)

display(df_with_markdown.style.set_caption("Results for get_text_by_text_with_markdown"))
display(df_with_text.style.set_caption("Results for get_text_by_text"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_b029d">
#   <caption>Results for get_text_by_text_with_markdown</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b029d_level0_col0" class="col_heading level0 col0" >Result</th>
#       <th id="T_b029d_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b029d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b029d_row0_col0" class="data row0 col0" >データに2024年5月のQ4のFacilityの経費に関する情報は</td>
#       <td id="T_b029d_row0_col1" class="data row0 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b029d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b029d_row1_col0" class="data row1 col0" >該当する情報は見つかりませんでした。</td>
#       <td id="T_b029d_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b029d_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_b029d_row2_col0" class="data row2 col0" >該当するデータはありません。</td>
#       <td id="T_b029d_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b029d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b029d_row3_col0" class="data row3 col0" >コンテキストに2024/5のQ4のFacilityの経費に関する</td>
#       <td id="T_b029d_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b029d_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_b029d_row4_col0" class="data row4 col0" >コンテキストに2024年5月のQ4のFacilityの経費に関する</td>
#       <td id="T_b029d_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b029d_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_b029d_row5_col0" class="data row5 col0" >データに2024/5のQ4のFacilityの経費はありません</td>
#       <td id="T_b029d_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b029d_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_b029d_row6_col0" class="data row6 col0" >コンテキストには2024/5のQ4のFacilityの経費に関する</td>
#       <td id="T_b029d_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b029d_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_b029d_row7_col0" class="data row7 col0" >データに2024/5のQ4のFacilityの経費は記載されて</td>
#       <td id="T_b029d_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b029d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b029d_row8_col0" class="data row8 col0" >コンテキストには、2024年5月のQ4のFacilityの経費</td>
#       <td id="T_b029d_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b029d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b029d_row9_col0" class="data row9 col0" >コンテキスト内に2024/5のQ4のFacilityの経費に関する</td>
#       <td id="T_b029d_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9c609">
#   <caption>Results for get_text_by_text</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c609_level0_col0" class="col_heading level0 col0" >Result</th>
#       <th id="T_9c609_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c609_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c609_row0_col0" class="data row0 col0" >1622</td>
#       <td id="T_9c609_row0_col1" class="data row0 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_9c609_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c609_row1_col0" class="data row1 col0" >431</td>
#       <td id="T_9c609_row1_col1" class="data row1 col1" >7</td>
#     </tr>
#   </tbody>
# </table>
